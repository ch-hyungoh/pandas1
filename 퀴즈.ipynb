# %%
import numpy as np
import networkx as nx
G = nx.karate_club_graph()
degree = [d for n,d in G.degree()]
nx.draw(G, with_labels= True, node_size=[n*100 for n in degree], node_color='yellow', edge_color = 'red')
a = G.degree
print(a)
b = dict(a)
maxnum = max(b.values())
print(maxnum)
c= {v:k for k, v in b.items()}
print(c[maxnum])
# Out:
# [(0, 16), (1, 9), (2, 10), (3, 6), (4, 3), (5, 4), (6, 4), (7, 4), (8, 5), (9, 2), (10, 3), (11, 1), (12, 2), (13, 5), (14, 2), (15, 2), (16, 2), (17, 2), (18, 2), (19, 3), (20, 2), (21, 2), (22, 2), (23, 5), (24, 3), (25, 3), (26, 2), (27, 4), (28, 3), (29, 4), (30, 4), (31, 6), (32, 12), (33, 17)]
# 17
# 33

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("연령별.csv", engine='python')
data.head()
# Out:
#       업태별      시도     시군구     연령별  (전체)당월  (전체)전월 (전체)전년동월  (개인)당월  (개인)전월  \
# 0  농·임·어업  30세 미만  30세 미만  30세 미만   1,622   1,578    1,463   1,296   1,261
# 1  농·임·어업  30세 이상  30세 이상  30세 이상   7,247   7,118    6,860   5,605   5,517
# 2  농·임·어업  40세 이상  40세 이상  40세 이상  15,661  15,487   14,850  11,622  11,499
# 3  농·임·어업  50세 이상  50세 이상  50세 이상  29,626  29,390   29,892  21,807  21,648
# 4  농·임·어업  60세 이상  60세 이상  60세 이상  30,712  30,627   27,646  23,925  23,847
#
#   (개인)전년동월 (법인)당월 (법인)전월 (법인)전년동월  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# 0    1,145    326    317      318          NaN          NaN          NaN
# 1    5,320  1,642  1,601    1,540          NaN          NaN          NaN
# 2   10,942  4,039  3,988    3,908          NaN          NaN          NaN
# 3   22,134  7,819  7,742    7,758          NaN          NaN          NaN
# 4   21,601  6,787  6,780    6,045          NaN          NaN          NaN
#
#    Unnamed: 16
# 0          NaN
# 1          NaN
# 2          NaN
# ...

# %%
import matplotlib.pyplot as plt
from numpy import NaN
import pandas as pd
data = pd.read_csv("성별.csv", engine='python')
group_names = ['저급', '중급', '고급']
data['Level'], mybin = pd.cut(data['(전체)당월'], 3, labels=group_names, retbins=True)
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-04574a681201> in <module>
#       4 data = pd.read_csv("성별.csv", engine='python')
#       5 group_names = ['저급', '중급', '고급']
# ----> 6 data['Level'], mybin = pd.cut(data['(전체)당월'], 3, labels=group_names, retbins=True)
#       7 data
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     220             raise ValueError("Cannot cut empty array")
#     221
# --> 222         rng = (nanops.nanmin(x), nanops.nanmax(x))
#     223         mn, mx = [mi + 0.0 for mi in rng]
#     224
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     123                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     124             else:
# ...
